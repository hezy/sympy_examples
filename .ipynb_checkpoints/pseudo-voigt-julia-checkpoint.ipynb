# %%
using Plots
using SpecialFunctions

# %%
x = range(start=-3, stop=3, step=0.01)
# Out:
# -3.0:0.01:3.0

# %%
function Lorentzian(x, fwhm)
    γ = fwhm / 2
    return @. (γ/pi) / (x^2 + γ^2)
end
# Out:
# Lorentzian (generic function with 1 method)

# %%
function Gaussian(x, fwhm)
    σ = fwhm/(2√(2log(2)))
    return @. 1/√(2π)/σ * exp(-x^2/2σ^2)
end
# Out:
# Gaussian (generic function with 1 method)

# %%
function pseudo_Voigt(x, fwhm, n)
	return n * Lorentzian(x, fwhm) + (1 - n) * Gaussian(x, fwhm)
end
# Out:
# pseudo_Voigt (generic function with 1 method)

# %%
function Voigt(x, fwhm_l, fwhm_g)
    γ = fwhm_l/2
    σ = fwhm_g/(2√(2log(2)))
    z = @. -im * (x + im * γ) / (√2 * σ)
    return @. real(erfcx(z)) / (√(2pi) * σ)
end
# Out:
# Voigt (generic function with 1 method)

# %%
y1 = Lorentzian(x, 1)
y2 = Gaussian(x, 1)
y3 = pseudo_Voigt(x, 1, 0.5)
y4 = Voigt(x, 0.45, 0.72)
# Out:
# 601-element Vector{Float64}:
#  0.008169967376146009
#  0.008226203762819528
#  0.00828302839824159
#  0.008340449597415006
#  0.008398475824300556
#  0.00845711569506493
#  0.008516377981412589
#  0.008576271614003912
#  0.00863680568596234
#  0.008697989456473121
#  0.008759832354476497
#  0.008822343982458146
#  0.008885534120339956
#  ⋮
#  0.008822343982458146
#  0.008759832354476497
#  0.008697989456473121
#  0.00863680568596234
#  0.008576271614003912
#  0.008516377981412589
#  0.00845711569506493
#  0.008398475824300556
#  0.008340449597415006
#  0.00828302839824159
#  0.008226203762819528
#  0.008169967376146009

# %%
p = plot(x, [y1 y2 y3 y4],
         label=["Lorentzian" "Gaussian" "Pseudo Voigt" "Voigt"])
title!("peak functions")
xlabel!(raw"x")
ylabel!(raw"y")
